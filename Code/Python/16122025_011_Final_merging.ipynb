# %%
import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.api as sm
import os
sns.set_theme()
from sklearn.preprocessing import LabelEncoder
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
cwd = os.getcwd()
print("Current working directory:", cwd)

# Change the working directory
#os.chdir('S:/OneDrive - University of Georgia/1 UGA/1 PhD/1 Spring24/Tobacco')
#os.chdir(r'/Users/sus/Library/CloudStorage/OneDrive-UniversityofGeorgia/1 UGA/1 PhD/1 Spring24/Tobacco')

os.chdir(r'/Users/sus/Library/CloudStorage/OneDrive-UniversityofGeorgia/1 UGA/1 PhD/Fall25/First_Chapter/madeData')

# Verify the change
print("New working directory:", os.getcwd())
# Out:
# Current working directory: /Users/sus/Library/CloudStorage/OneDrive-UniversityofGeorgia/1 UGA/1 PhD/Fall25/First_chapter/madeData
# New working directory: /Users/sus/Library/CloudStorage/OneDrive-UniversityofGeorgia/1 UGA/1 PhD/Fall25/First_chapter/madeData

# %%
df1 = pd.read_csv('heat_smoke_market_FINAL.csv')
df2 = pd.read_csv('INCOME_FINAL.csv')
df3 = pd.read_csv('price_indices_FINAL.csv')
df4 = pd.read_csv('other_var_FINAL.csv')

# %% [markdown]
# Lets MERGEEEE

# %%
## merging these two datasets on W and region variables:
merged_df1 = pd.merge(df1, df3, on=['W', 'region'], how='inner')
merged_df2 = pd.merge(merged_df1, df4, on=['W', 'region'], how='inner')
merged_FINAL = pd.merge(merged_df2, df2, on=['region', 'year'], how='inner')

# %%
merged_FINAL
# Out:
#         W  region  year  totrev_Smoke   qt_Smoke  totrev_Heat   qt_Heat  \
# 0       1       1  2017  2.574840e+06   5578.204   209494.044   414.742
# 1       1       2  2017  2.729862e+06   5567.702   150458.728   296.045
# 2       1       3  2017  1.046158e+06   2116.976    57934.923   112.455
# 3       1       4  2017  3.198163e+06   7037.711   213254.932   439.983
# 4       1       5  2017  1.337419e+07  29068.790  1035634.873  2102.634
# ...   ...     ...   ...           ...        ...          ...       ...
# 2191  183       8  2020  4.984312e+05   1075.484   164780.339   336.905
# 2192  183       9  2020  1.348564e+06   2465.845   371034.720   680.921
# 2193  183      10  2020  1.347240e+06   2565.614   503146.661   950.301
# 2194  183      11  2020  3.096018e+06   6137.084  1330899.271  2506.863
# 2195  183      12  2020  4.644789e+06   8551.305  2057522.963  3654.706
#
#       Laspeyres_Smoke  Paasche_Smoke  Fisher_Smoke  ...  Laspeyres_Heat  \
# ...

# %%
# processing merged final into removing the national region

merged_FINAL = merged_FINAL[merged_FINAL['region']!=13]
merged_FINAL
# Out:
#         W  region  year  totrev_Smoke   qt_Smoke  totrev_Heat   qt_Heat  \
# 0       1       1  2017  2.574840e+06   5578.204   209494.044   414.742
# 1       1       2  2017  2.729862e+06   5567.702   150458.728   296.045
# 2       1       3  2017  1.046158e+06   2116.976    57934.923   112.455
# 3       1       4  2017  3.198163e+06   7037.711   213254.932   439.983
# 4       1       5  2017  1.337419e+07  29068.790  1035634.873  2102.634
# ...   ...     ...   ...           ...        ...          ...       ...
# 2191  183       8  2020  4.984312e+05   1075.484   164780.339   336.905
# 2192  183       9  2020  1.348564e+06   2465.845   371034.720   680.921
# 2193  183      10  2020  1.347240e+06   2565.614   503146.661   950.301
# 2194  183      11  2020  3.096018e+06   6137.084  1330899.271  2506.863
# 2195  183      12  2020  4.644789e+06   8551.305  2057522.963  3654.706
#
#       Laspeyres_Smoke  Paasche_Smoke  Fisher_Smoke  ...  Laspeyres_Heat  \
# ...

# %%
merged_FINAL.to_csv('FINAL_Chapter1.csv', index=False)
